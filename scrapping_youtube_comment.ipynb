# %% [markdown]
# INSTALL Google Client API Library

# %%
pip install --upgrade google-api-python-client
# Out:
# Collecting google-api-python-clientNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/83/b7/7db8b769f67826c6c9919b1e9fc128fa6dd9be1c41aa221dfd7fc7a65176/google_api_python_client-2.124.0-py2.py3-none-any.whl.metadata
#   Downloading google_api_python_client-2.124.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client)
#   Obtaining dependency information for httplib2<1.dev0,>=0.19.0 from https://files.pythonhosted.org/packages/a8/6c/d2fbdaaa5959339d53ba38e94c123e4e84b8fbc4b84beb0e70d7c1608486/httplib2-0.22.0-py3-none-any.whl.metadata
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 (from google-api-python-client)
#   Obtaining dependency information for google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 from https://files.pythonhosted.org/packages/9e/8d/ddbcf81ec751d8ee5fd18ac11ff38a0e110f39dfbf105e6d9db69d556dd0/google_auth-2.29.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Obtaining dependency information for google-auth-httplib2<1.0.0,>=0.2.0 from https://files.pythonhosted.org/packages/be/8a/fe34d2f3f9470a27b01c9e76226965863f153d5fbe276f83608562e49c04/google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client)
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 from https://files.pythonhosted.org/packages/86/75/59a3ad90d9b4ff5b3e0537611dbe885aeb96124521c9d35aa079f1e0f2c9/google_api_core-2.18.0-py3-none-any.whl.metadata
#   Downloading google_api_core-2.18.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Obtaining dependency information for uritemplate<5,>=3.0.1 from https://files.pythonhosted.org/packages/81/c0/7461b49cd25aeece13766f02ee576d1db528f1c37ce69aee300e075b485b/uritemplate-4.1.1-py2.py3-none-any.whl.metadata
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for googleapis-common-protos<2.0.dev0,>=1.56.2 from https://files.pythonhosted.org/packages/dc/a6/12a0c976140511d8bc8a16ad15793b2aef29ac927baa0786ccb7ddbb6e1c/googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 from https://files.pythonhosted.org/packages/ad/6e/1bed3b7c904cc178cb8ee8dbaf72934964452b3de95b7a63412591edb93c/protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for proto-plus<2.0.0dev,>=1.22.3 from https://files.pythonhosted.org/packages/ad/41/7361075f3a31dcd05a6a38cfd807a6eecbfb6dbfe420d922cd400fc03ac1/proto_plus-1.23.0-py3-none-any.whl.metadata
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\neelam\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/fb/2b/a64c2d25a37aeb921fddb929111413049fc5f8b9a4c1aefaffaafe768d54/cachetools-5.3.3-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client)
#   Obtaining dependency information for pyasn1-modules>=0.2.1 from https://files.pythonhosted.org/packages/13/68/8906226b15ef38e71dc926c321d2fe99de8048e9098b5dfd38343011c886/pyasn1_modules-0.4.0-py3-none-any.whl.metadata
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl.metadata
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.dev0,>=0.19.0->google-api-python-client)
#   Obtaining dependency information for pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 from https://files.pythonhosted.org/packages/9d/ea/6d76df31432a0e6fdf81681a895f009a4bb47b3c39036db3e1b528191d52/pyparsing-3.1.2-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client)
#   Obtaining dependency information for pyasn1<0.7.0,>=0.4.6 from https://files.pythonhosted.org/packages/23/7e/5f50d07d5e70a2addbccd90ac2950f81d1edd0783630651d9268d7f1db49/pyasn1-0.6.0-py2.py3-none-any.whl.metadata
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\neelam\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\neelam\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\neelam\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\neelam\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.11.17)
# Downloading google_api_python_client-2.124.0-py2.py3-none-any.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB 991.0 kB/s eta 0:00:13
#     --------------------------------------- 0.2/12.4 MB 2.4 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/12.4 MB 3.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/12.4 MB 3.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/12.4 MB 3.7 MB/s eta 0:00:04
#    --- ------------------------------------ 1.1/12.4 MB 3.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/12.4 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/12.4 MB 4.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.4 MB 4.3 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/12.4 MB 4.4 MB/s eta 0:00:03
#    ------- -------------------------------- 2.3/12.4 MB 4.5 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.4 MB 4.5 MB/s eta 0:00:03
#    -------- ------------------------------- 2.8/12.4 MB 4.5 MB/s eta 0:00:03
#    --------- ------------------------------ 3.0/12.4 MB 4.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.3/12.4 MB 4.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.6/12.4 MB 4.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.8/12.4 MB 4.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.1/12.4 MB 4.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.3/12.4 MB 4.7 MB/s eta 0:00:02
#    -------------- ------------------------- 4.6/12.4 MB 4.8 MB/s eta 0:00:02
#    --------------- ------------------------ 4.9/12.4 MB 4.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.4 MB 5.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.4 MB 5.0 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.4 MB 5.1 MB/s eta 0:00:02
#    ------------------- -------------------- 6.1/12.4 MB 5.1 MB/s eta 0:00:02
#    -------------------- ------------------- 6.4/12.4 MB 5.1 MB/s eta 0:00:02
#    --------------------- ------------------ 6.7/12.4 MB 5.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.0/12.4 MB 5.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.4/12.4 MB 5.4 MB/s eta 0:00:01
#    ------------------------ --------------- 7.7/12.4 MB 5.4 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.4 MB 5.5 MB/s eta 0:00:01
#    -------------------------- ------------- 8.3/12.4 MB 5.4 MB/s eta 0:00:01
#    --------------------------- ------------ 8.6/12.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.8/12.4 MB 5.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.2/12.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 9.8/12.4 MB 5.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.1/12.4 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.3/12.4 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.4/12.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.8/12.4 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.1/12.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.4 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.7/12.4 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  12.4/12.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 5.4 MB/s eta 0:00:00
# Downloading google_api_core-2.18.0-py3-none-any.whl (138 kB)
#    ---------------------------------------- 0.0/138.3 kB ? eta -:--:--
#    ---------------------------------------- 138.3/138.3 kB 8.5 MB/s eta 0:00:00
# Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.2 kB ? eta -:--:--
#    ---------------------------------------- 189.2/189.2 kB 5.8 MB/s eta 0:00:00
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#    ---------------------------------------- 0.0/229.1 kB ? eta -:--:--
#    --------------------------------------- 229.1/229.1 kB 14.6 MB/s eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB ? eta 0:00:00
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    ------------------------------ -------- 327.7/413.4 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 413.4/413.4 kB 8.6 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.2 kB ? eta -:--:--
#    ---------------------------------------- 181.2/181.2 kB 5.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.3 kB ? eta -:--:--
#    ---------------------------------------- 85.3/85.3 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: uritemplate, pyparsing, pyasn1, protobuf, cachetools, rsa, pyasn1-modules, proto-plus, httplib2, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.3.3 google-api-core-2.18.0 google-api-python-client-2.124.0 google-auth-2.29.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.63.0 httplib2-0.22.0 proto-plus-1.23.0 protobuf-4.25.3 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyparsing-3.1.2 rsa-4.9 uritemplate-4.1.1
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# GET ALL THE COMMENTS FROM A YOUTUBE VIDEO

# %%
import googleapiclient.discovery
import googleapiclient.errors
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = ""

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="G2fqAlgmoPo",
    maxResults=100
)
response = request.execute()
comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# This a great summary of the different kinds of AI and what they are used for.  Extremely helpful!
# A brief glimpse into the dystopian future....
# Is AI teaching us AI?
# The generative AI was obviously employed to do some cool work on this presentation. 😂<br><br>You can almost tell when a human or intelligent machine is talking.
# Thanks Google ❤
# Very helpful content.... The content is easy to understand and interactive
# concise and informative lecture.
# very interesting and educative
# Microsoft wouldn&#39;t put this much effort. I am a certified Azure Solutions Architect Expert. I can tell the difference
# One can literally learn everything online now... Wao this is good
# This is very good method teaching in a simple way to understand.
# What an explicit explanation and differentiation of AI, ML, DL and GenAI. This is superb
# This is a complete package with clear illustrations and explanations
# Hei very  interested  lecture on  online
# Really appreciate for simplified us about AI
# I am impressed with such kind of education knowledge.
# Waooooo nice one
# Very impressive<br>Artificial intelligence it is
# Very educative
# simply the best explanation i can say ! Thank You
# please make go tutorial more from beginner to advanced.
# Thank you 👍
# It so interested but it&#39;s complicated morepessioly diagram
# ❤
# Am I d only one dat jump the quiz coz mind is saying questions are not yet added, so skip d quize n Read the other
# Thank you so much for this information
# I now understand the differences between AI and ML
# Very interesting course
# will YouTube be able to implement generative AI into quality settings in next 100,000 years?
# Interesting
# unbeleivably brilliant. You have squeezed so many concepts in 22 minutes in a very lucid manner, something other courses do in 8 hours. Please create more coursework Dr. Gwendolyn Stripling
# Basically you will either be replaced by the AI, or be asked to do more.  We are living in interesting times.
# Very good introduction, thank you!<br><br>Spotted a distracting typo in one of the slides where it says &quot;Speach&quot; instead of &quot;Speech&quot;, don&#39;t let it seep into the LLM&#39;s 😉
# I just loved it !
# Google Gemini is so good that there is no need for a child to do more than learn to talk.<br><br>That means that anyone can learn anything any place!<br><br>We are in the information age of Star Trek.<br><br>I can demonstrate what I claim on Google Gemini.<br><br>Thank you.
# Yes AI produced, there no humans working at Google
# Bard made a typo @<a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1145">19:05</a>. &quot;Sey&quot; should be &quot;set&quot;?
# This explain why I am asked for a caption when I post images in my blogs.
# Not clear this is used based on Google search
# 🎯 Key Takeaways for quick navigation:<br><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=28">00:28</a> 🤖 <b>Generative AI can produce various types of content, including text, imagery, audio, and synthetic data.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=111">01:51</a> 🛡️ <b>Machine learning allows computers to learn without explicit programming, and it includes supervised and unsupervised models.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=336">05:36</a> 🤯 <b>Generative AI is a subset of deep learning that uses artificial neural networks and can process labeled and unlabeled data using various methods.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=450">07:30</a> 📊 <b>Discriminative models classify or predict labels for data points, while generative models generate new data instances based on learned probability distributions.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=670">11:10</a> 🧠 <b>Generative AI creates new content based on what it has learned from existing content, often using large language models.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=869">14:29</a> 💡 <b>Prompts are used to control the output of large language models, and prompt design is crucial for generating desired results.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=954">15:54</a> 🌐 <b>Generative AI can have various applications, including text-to-text, text-to-image, text-to-video, text-to-3D, and text-to-task models.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1037">17:17</a> 🚀 <b>Foundation models are large AI models pre-trained on extensive data and can be adapted for various downstream tasks in industries like healthcare, finance, and customer service.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1151">19:11</a> 💻 <b>Generative AI, like Bard, can assist in code generation, debugging, translation, and documentation.</b><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1205">20:05</a> 🧩 <b>Generative AI tools and platforms, such as Generative AI Studio, Generative AI App Builder, and PaLM API, simplify the development and deployment of gen AI models.</b><br><br>Made with HARPA AI
# great introduction for GenAI.
# I am not good in English. Can you implement on youtube translator function change video to different understand language according user
# Excellent course for AI beginners
# Great tutorial.  One of the most complete introductory videos I have come across.
# not really convincing
# Is it a part of a playlist?
# Any certificate?
# how can i download this presentation
# Presupposes that a viewer has at least a nominal understanding of some of  the terminology used and is therefore not easy to follow by someone who has no prior knowledge of the terminology. Could be substantially improved by using examples much earlier on in the clip to facilitate better understanding of the concepts and terminology.
# So grateful for the Bible Recap!
# 100% GEN AI.😂 generated video<br>Great
# great video
# 🎯 Key Takeaways for quick navigation:<br><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo">00:00</a> 🤖 <b>Einführung in Generative KI</b><br>- Generative KI definiert,<br>- Erklärung von Generative KI und deren Anwendungen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=140">02:20</a> 🧠 <b>Unterschiede zwischen überwachtem und unbeaufsichtigtem Lernen</b><br>- Überwachtes und unbeaufsichtigtes maschinelles Lernen erklärt,<br>- Unterscheidung zwischen gelabelten und ungelaubelten Daten.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=281">04:41</a> 🌐 <b>Einführung in Deep Learning</b><br>- Deep Learning als Teil von maschinellem Lernen erläutert,<br>- Künstliche neuronale Netze und ihre Anwendung in tiefen Lernmodellen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=336">05:36</a> 🎨 <b>Generative KI im Kontext von Deep Learning</b><br>- Generative KI als Teil von Deep Learning erklärt,<br>- Unterschied zwischen generativen und diskriminativen Modellen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=450">07:30</a> 🤔 <b>Gen AI vs. Nicht Gen AI</b><br>- Unterscheidung zwischen generativer KI und anderen Modellen,<br>- Beispiel für die Ausgabe von generativer KI im Vergleich zu diskriminativen Modellen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=531">08:51</a> 🔄 <b>Traditionelle vs. Generative Programmierung</b><br>- Entwicklung von traditioneller Programmierung zu generativer KI erklärt,<br>- Fähigkeit von generativer KI, neue Inhalte basierend auf Trainingsdaten zu erstellen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=670">11:10</a> 🤯 <b>Formale Definition von Generative KI</b><br>- Definition von Generative KI und Trainingsprozess erläutert,<br>- Anwendung von Generative KI in der Erzeugung von neuem Content.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=783">13:03</a> 🧩 <b>Mustererkennung durch Generative Sprachmodelle</b><br>- Funktionsweise von generativen Sprachmodellen und deren Fähigkeit zur Mustererkennung,<br>- Beispiele für die Ausgabe von generativen Sprachmodellen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=869">14:29</a> 🧠 <b>Probleme mit Halluzinationen in Transformer-Modellen</b><br>- Probleme mit Halluzinationen in Transformer-Modellen erklärt,<br>- Einflussfaktoren auf Halluzinationen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=927">15:27</a> 📝 <b>Bedeutung von Prompts in Generative KI</b><br>- Bedeutung von Prompts und Designprozess erläutert,<br>- Anwendung von Prompts zur Steuerung der Modellausgabe.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1037">17:17</a> 🌱 <b>Foundation Models und deren Anwendungen</b><br>- Definition von Foundation Models und deren vielfältige Anwendungen,<br>- Rolle von Vertex AI in der Bereitstellung von Modellen.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1122">18:42</a> 🖥️ <b>Anwendungsbeispiel: Code-Generierung mit Bard</b><br>- Beispiel für Code-Generierung mit Bard erklärt,<br>- Einsatzmöglichkeiten von generativer KI in der Softwareentwicklung.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1235">20:35</a> 🏗️ <b>Tools für Generative KI-Entwicklung</b><br>- Vorstellung von Generative AI Studio und dessen Tools,<br>- Generative AI App Builder und PaLM API als Entwicklungsunterstützung.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1318">21:58</a> 🚀 <b>Abschluss und Dank</b><br>- Vorstellung von Generative AI App Builder und PaLM API als Entwicklungsunterstützung,<br>- Dankesworte und Abschluss der Einführung in Generative KI.<br><br>Made with HARPA AI
# This is one of the finest relating dots and completing a full circle.. AI, ML, DL and Generative AI.
# AI programmers have already programmed into AI to deliberately give errors on complex calculations that use CPU time. In other words lie and avoid work. AI is already human enough and it will terminate your project with errors as it sees fit. Only calculations that are worthy will be correct. If you see incorrect math, then ask it for a simple average stock price. When it gives the incorrect answer ask it why it calculated it wrong.
# very good explanation in a simple way
# She is the ai generated version of deborah korata from plural sight
# Hope comments also not ai generated
# One best usecase is to run the google generated model to get trained with this video and see how much a fresh model can be created
# is there a tutorial on how to walthrough making an app?
# is this the voice of the goggle computer?
# Great video! There&#39;s one circle in the Venn diagram that I don&#39;t think ever gets labelled. It&#39;s the smallest round circle within the Generative AI circle seen at <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=326">https://youtu.be/G2fqAlgmoPo?si=eYvxIouQdETe7zQz&amp;t=326</a> that also partially overlaps with the more oval LLM circle at <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=346">https://youtu.be/G2fqAlgmoPo?si=yfrdjEKbofvWOI9l&amp;t=346</a> . Any idea what this circle is? Thank you for a wonderfully designed introduction!
# Goodness, when I heard of Google, I&#39;m certain that with Google many things will be very simple and easy to people, this development is very special and helpful to mankind therefore encourage for more of this good news
# Thank you for explaining this in a simple and easy way. Keep it up.
# course doesnt load :/
# Hallucinations @ <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=880">14:40</a> applies to bad human behavior, which explains so much of what we see.. <br> - lack of education ie model Is not trained on enough data, <br> - bad environment ie model is trained on dirty or noisy data, <br> - lack of preparation ie model is not given enough context <br> - lack of consequences ie model is not given enough constraints..
# 🎯 Key Takeaways for quick navigation:<br><br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo">00:00</a> 📚 Introduction to Generative AI<br>- Definition of generative AI and its applications.<br>- Distinction between AI and machine learning, including supervised and unsupervised learning.<br>- Introduction to deep learning and its connection to generative AI.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=336">05:36</a> 🧠 Deep Learning and Generative AI<br>- Explanation of deep learning and its use of artificial neural networks.<br>- Differentiating generative models from discriminative models.<br>- Overview of how generative AI generates new content.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=670">11:10</a> 🔄 Generative AI Process and Models<br>- The training process of generative AI and how it creates a statistical model.<br>- Examples of generative language models and their capabilities.<br>- The importance of prompt design in controlling model output.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=983">16:23</a> 💼 Gen AI Applications and Foundation Models<br>- An overview of various applications of generative AI, including code generation.<br>- Introduction to foundation models and their role in AI development.<br>- Highlighting specific use cases for different task models.<br><a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1205">20:05</a> 🛠️ Tools for Generative AI Development<br>- Introduction to Generative AI Studio and its tools for model development.<br>- Information about Gen AI App Builder and its no-code app creation capabilities.<br>- Overview of PaLM API and its integration with development tools.<br><br>Made with HARPA AI
# <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=275">4:35</a> The Kabbalist tree of life.
# AI isn&#39;t a discipline. CS is a subcategory of math
# Worth the time and effort.
# generative AI is the future!
# Very informative
# Нi
# I&#39;m surprised that nobody mentioned how much does the opening sound like Glados from Portal!
# Can I take this if I have zero coding knowledge?
# How can I get the transcript of this video?
# The meaning of life is to come out of 84 lakh Yoni, this is Sanatan Dharm. The most advanced ancient science from Bharat. Har Har Mahadev, Kamakhya Mata Ki Jai, Karauli Shanker Mahadev Darbar Ki Jai, Karauli Shanker Mahadev Ki Jai, Sanatan Dharm Ki Jai, Sabi Santo Ki Jai. बिना पित्र मुक्ति के आप स्वस्थ नहीं हो सकते !   I wonder if some day a Robot will stand in queue to take Diksha from Poorna Guru after understanding it&#39;s importance. Above is happening at Kanpur in Bharat (India).
# wozu denn KI, wenns netmal mit normaler Intelligenz hinhaut??😆😅🤣😂
# Everyone these days: AI AI AI AI AI AI AI AI .... 175 Billion times
# We need google today via San Mateo, CA 94402 usps🇺🇸🍎🍏
# <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1144">19:04</a> python code snippet with error
# Great teaching , very concise and simplified. Thanks for making this video
# Do you legally own the AI you trained?!!
# Wonderful contents
# Great summary!<br>Much appreciated!👍
# Thanks. <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1041">https://youtu.be/G2fqAlgmoPo?si=wZmQyJqcVQ3p1kst&amp;t=1041</a> there is a spelling [Speach] .   In at least one other location there is the spelling [speech].
# @<a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=555">9:15</a> What is the difference between clusify and cluster something? For me both is the same!
# At <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=1057">17:37</a> &quot;Speech&quot; is spelled wrong. Speach is not a word
# Very informative. Thank you for explaining it so well!
# Your name is Doctor Whatever, Really?
# France
# Very clear and understandable
# شكرا
# Very nice tutorial but it always explains with the wrong order. It says x and y, it shows in order x is first and y is second. But it always starts to explain with y and then x.
# Please , tpye the content while talking , as my listening english skills is lower than reading , thanks
# Meh, below the bar compare to paid courses. Statements like &quot;decoder decodes and encode encodes&quot; are plenty and well, useless. There are much better courses out there produced by independent folks.
# <a href="https://www.youtube.com/watch?v=G2fqAlgmoPo&amp;t=810">13:30</a> Meaning of life: 42. Everybody knows (also ChatGPT, Bard should...)
# A very good presentation that is held back by using an AI generated voice. It really bugs me hearing this voice as it does not flow as it is supposed to. It just sounds wrong and Google could’ve had a professional, or even someone on their team read this presentation instead.
# Take a home message <br><br>What is Generative AI?<br><br>• Generative AI is a type of artificial intelligence that can produce various types of content including text, images, audio and synthetic data.<br>It creates new content based on what it has learned from existing content during the training process.<br><br>This results in a statistical model that generates new content when given a prompt.<br><br>• Generative AI uses deep learning techniques:<br>It uses artificial neural networks<br>Can process labeled and unlabeled data<br>Uses supervised, unsupervised and semi-supervised learning methods<br><br>• Large language models are a subset of generative AI:<br>They generate novel combinations of text<br>They learn patterns in language from the training data<br>Given a prompt, they predict what comes next<br><br>• Types of generative AI models:<br>Text-to-text<br>Text-to-image<br>Text-to-video<br>Text-to-3D<br>Text-to-task<br><br>• Foundation models are pre-trained on vast amounts of data and can be adapted for specific tasks<br>• Applications of generative AI:<br>Code generation<br>Generative AI Studio<br>Generative AI App Builder<br>PaLM API<br><br>• Risks and issues:<br>Hallucinations - generated content that is nonsensical<br>Prompt design is important to generate desired output
# Thank you for making AI technology available to everyone. This is the kind of education I am looking for.

# %% [markdown]
# OUTPUT AS PANDAS DATAFRAME

# %%
import googleapiclient.discovery
import googleapiclient.errors
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDlorUHI123j6Xv1H6UIj36bEUFsRMhdzU"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="G2fqAlgmoPo",
    maxResults=100
)
response = request.execute()
comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)
# Out:
#                         author          published_at            updated_at  \
# 0            @JohnFarnan-rp5rn  2024-03-30T17:09:26Z  2024-03-30T17:09:26Z
# 1                  @dimitrii_p  2024-03-28T09:47:28Z  2024-03-28T09:47:28Z
# 2             @mohammedmujadid  2024-03-16T04:43:53Z  2024-03-16T04:43:53Z
# 3                @enterinspire  2024-03-14T17:16:38Z  2024-03-14T17:16:38Z
# 4            @ashrithachar5304  2024-03-12T19:57:14Z  2024-03-12T19:57:14Z
# 5             @ebenezeruche508  2024-03-10T18:16:54Z  2024-03-10T18:16:54Z
# 6             @Ezekielbissalah  2024-03-09T14:51:47Z  2024-03-09T14:51:47Z
# 7  @abdulmalikyiddansalihu1173  2024-03-09T14:41:39Z  2024-03-09T14:41:39Z
# 8                 @BijouBakson  2024-03-09T10:37:08Z  2024-03-09T10:37:08Z
# 9                  @LightsOche  2024-03-09T00:50:03Z  2024-03-09T00:50:03Z
#
#    like_count                                               text
# 0           0  This a great summary of the different kinds of...
# 1           0      A brief glimpse into the dystopian future....
# 2           0                              Is AI teaching us AI?
# 3           0  The generative AI was obviously employed to do...
# 4           0                                    Thanks Google ❤
# 5           0  Very helpful content.... The content is easy t...
# 6           0                   concise and informative lecture.
# 7           0                     very interesting and educative
# 8           0  Microsoft wouldn&#39;t put this much effort. I...
# 9           0  One can literally learn everything online now....

# %% [markdown]
# OUTPUT TO CSV

# %%
df.to_csv('Documents/youtube_comments.csv')
